# %% [markdown]
# # Data Manipulation and Presentation on COVID-19 World Database

# %%
# Made by 19csu035 and 19csu016

# %%
# importing pandas numpy and matplotlib.pyplot libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#this will allows to display graphs and charts without using plt.show()
# %matplotlib inline

# %%
#Reading csv file downloaded form Kagle 
# link: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset?select=covid_19_data.csv
df=pd.read_csv('covid_19_data.csv')

#changing index to Serial No.
df.set_index('SNo' , inplace = True)
df
# Out:
#        ObservationDate     Province/State  Country/Region      Last Update  \
# SNo
# 1           01/22/2020                NaN  Mainland China  1/22/2020 17:00
# 2           01/22/2020            Beijing  Mainland China  1/22/2020 17:00
# 3           01/22/2020          Chongqing  Mainland China  1/22/2020 17:00
# 4           01/22/2020             Fujian  Mainland China  1/22/2020 17:00
# 5           01/22/2020              Gansu  Mainland China  1/22/2020 17:00
# ...                ...                ...             ...              ...
# 156288      11/15/2020  Zaporizhia Oblast         Ukraine  16-11-2020 5.25
# 156289      11/15/2020            Zeeland     Netherlands  16-11-2020 5.25
# 156290      11/15/2020           Zhejiang  Mainland China  16-11-2020 5.25
# 156291      11/15/2020    Zhytomyr Oblast         Ukraine  16-11-2020 5.25
# 156292      11/15/2020       Zuid-Holland     Netherlands  16-11-2020 5.25
#
#         Confirmed  Deaths  Recovered
# SNo
# ...

# %% [markdown]
# # Following are the commands to check for missing data

# %%
df[df['Country/Region'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df['ObservationDate'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df['Last Update'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df['Confirmed'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df['Deaths'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df['Recovered'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df['Province/State'].isna() == True]
# Out:
#        ObservationDate Province/State      Country/Region      Last Update  \
# SNo
# 1           01/22/2020            NaN      Mainland China  1/22/2020 17:00
# 36          01/22/2020            NaN               Japan  1/22/2020 17:00
# 37          01/22/2020            NaN            Thailand  1/22/2020 17:00
# 38          01/22/2020            NaN         South Korea  1/22/2020 17:00
# 74          01/23/2020            NaN               Japan    1/23/20 17:00
# ...                ...            ...                 ...              ...
# 155700      11/15/2020            NaN  West Bank and Gaza  16-11-2020 5.25
# 155701      11/15/2020            NaN      Western Sahara  16-11-2020 5.25
# 155702      11/15/2020            NaN               Yemen  16-11-2020 5.25
# 155703      11/15/2020            NaN              Zambia  16-11-2020 5.25
# 155704      11/15/2020            NaN            Zimbabwe  16-11-2020 5.25
#
#         Confirmed  Deaths  Recovered
# SNo
# ...

# %%
'''#filt = df['Province/State'] == np.NaN .df['filt2'] 
def fun(a):
    filt= df['Country/Region']== a
    x= df[filt]['Province/State'].value_counts().head(1).index[0]
    return str(x)

df[filt]['Province/State'] = df[filt]['Country/Region'].apply(fun)
#df['Province/State'].fillna(value=x , inplace= True)
#df['Province/State'].replace('Unknown' , df['Country/Region'], inplace = True,method="pad")
#df['Province/State'].fillna(value=df['Country/Region'],inplace = True)
#df[df['Province/State'].isna() == True]
df'''
# Out:
# '#filt = df[\'Province/State\'] == np.NaN .df[\'filt2\'] \ndef fun(a):\n    filt= df[\'Country/Region\']== a\n    x= df[filt][\'Province/State\'].value_counts().head(1).index[0]\n    return str(x)\n\ndf[filt][\'Province/State\'] = df[filt][\'Country/Region\'].apply(fun)\n#df[\'Province/State\'].fillna(value=x , inplace= True)\n#df[\'Province/State\'].replace(\'Unknown\' , df[\'Country/Region\'], inplace = True,method="pad")\n#df[\'Province/State\'].fillna(value=df[\'Country/Region\'],inplace = True)\n#df[df[\'Province/State\'].isna() == True]\ndf'

# %%
# droping rows with missing values
df.dropna(axis=0, how='any', inplace= True)

# %%
# correction of SerialNo.
df.reset_index(inplace=True)
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            2      01/22/2020            Beijing  Mainland China
# 1            3      01/22/2020          Chongqing  Mainland China
# 2            4      01/22/2020             Fujian  Mainland China
# 3            5      01/22/2020              Gansu  Mainland China
# 4            6      01/22/2020          Guangdong  Mainland China
# ...        ...             ...                ...             ...
# 111973  156288      11/15/2020  Zaporizhia Oblast         Ukraine
# 111974  156289      11/15/2020            Zeeland     Netherlands
# 111975  156290      11/15/2020           Zhejiang  Mainland China
# 111976  156291      11/15/2020    Zhytomyr Oblast         Ukraine
# 111977  156292      11/15/2020       Zuid-Holland     Netherlands
#
#             Last Update  Confirmed  Deaths  Recovered
# 0       1/22/2020 17:00         14       0          0
# 1       1/22/2020 17:00          6       0          0
# ...

# %%
df['SNo']=df.index+1
df.set_index('SNo' , inplace = True)
df
# Out:
#        ObservationDate     Province/State  Country/Region      Last Update  \
# SNo
# 1           01/22/2020            Beijing  Mainland China  1/22/2020 17:00
# 2           01/22/2020          Chongqing  Mainland China  1/22/2020 17:00
# 3           01/22/2020             Fujian  Mainland China  1/22/2020 17:00
# 4           01/22/2020              Gansu  Mainland China  1/22/2020 17:00
# 5           01/22/2020          Guangdong  Mainland China  1/22/2020 17:00
# ...                ...                ...             ...              ...
# 111974      11/15/2020  Zaporizhia Oblast         Ukraine  16-11-2020 5.25
# 111975      11/15/2020            Zeeland     Netherlands  16-11-2020 5.25
# 111976      11/15/2020           Zhejiang  Mainland China  16-11-2020 5.25
# 111977      11/15/2020    Zhytomyr Oblast         Ukraine  16-11-2020 5.25
# 111978      11/15/2020       Zuid-Holland     Netherlands  16-11-2020 5.25
#
#         Confirmed  Deaths  Recovered
# SNo
# ...

# %%
# Number of Observation on each day
a=df['ObservationDate'].value_counts()
frame={'Date': a.index, 'Sum':a}
df1=pd.DataFrame(frame)
df1.set_index('Date', inplace = True)
df1
# Out:
#             Sum
# Date
# 11/14/2020  588
# 11/13/2020  588
# 11-12-2020  588
# 11/15/2020  588
# 10/16/2020  575
# ...         ...
# 01/26/2020   38
# 01/24/2020   35
# 01/23/2020   35
# 01/25/2020   35
# 01/22/2020   34
#
# [299 rows x 1 columns]

# %%
plt.figure(figsize=(50,900))
plt.barh(a.index, a, height=0.5)
# Out:
# <BarContainer object of 299 artists>

# %%
#Trend of Observations
observations = df.groupby('ObservationDate')['ObservationDate'].count()
plt.plot(observations.index, observations, color = 'b', label = 'Date Vs Observations')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Observations')
plt.xticks(a.index, " ")[1]
# Out:
# [Text(0, 0, ' ')]

# %%
#Trend of Confirmed Cases
confirmed = df.groupby('ObservationDate')['Confirmed'].sum()
plt.plot(confirmed.index, confirmed, color = 'orange', label = 'Date Vs Cases')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Cases per Day')
plt.xticks(confirmed.index, " ")[1]
# Out:
# [Text(0, 0, ' ')]

# %%
#Trend of Deaths
deaths = df.groupby('ObservationDate')['Deaths'].sum()
plt.plot(deaths.index, deaths, color = 'r', label = 'Date Vs Deaths')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Deaths per Day')
plt.xticks(deaths.index, " ")[1]
# Out:
# [Text(0, 0, ' ')]

# %%
#Trend of Recovered Patients
recovered = df.groupby('ObservationDate')['Recovered'].sum()
plt.plot(recovered.index, recovered, color = 'g', label = 'Date Vs Recovered Patients')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Recovered Patients per Day')
plt.xticks(recovered.index, " ")[1]
# Out:
# [Text(0, 0, ' ')]

# %%
# All Trends in one Graph
plt.figure(figsize=(10,10))

plt.plot(observations.index, observations, color = 'b', label = 'Date Vs Observations' , lw=3)
plt.plot(confirmed.index, confirmed, color = 'orange', label = 'Date Vs Cases' , lw=3)
plt.plot(deaths.index, deaths, color = 'r', label = 'Date Vs Deaths' , lw=3)
plt.plot(recovered.index, recovered, color = 'g', label = 'Date Vs Recovered Patients' , lw=3)
plt.legend()
plt.xlabel('Date')
plt.xticks(recovered.index, '')[1]
# Out:
# []

# %%
# storing values for ploting
avg_confirmed=df['Confirmed'].mean()
avg_deaths=df['Deaths'].mean()
avg_recovered=df['Recovered'].mean()

max_confirmed=df['Confirmed'].max()
max_deaths=df['Deaths'].max()
max_recovered=df['Recovered'].max()

# %%
# ploting average and maximum values
fig, axes = plt.subplots(1,2,figsize=(16,5))
axes[0].bar(['Confirmed','Deaths','Recovered'], [max_confirmed,max_deaths,max_recovered])
axes[0].set_title('Maximum Values')
axes[1].bar(['Confirmed','Deaths','Recovered'], [avg_confirmed,avg_deaths,avg_recovered], color='orange')
axes[1].set_title('Average Values')
# Out:
# Text(0.5, 1.0, 'Average Values')

# %%
total_cases = df['Confirmed'].sum()
death_toll = df['Deaths'].sum()
total_recovered = df['Recovered'].sum()

# %%
d1={'Total cases': total_cases, 'Death Toll': death_toll, 'Total Recovered': total_recovered}
df2=pd.DataFrame(d1, index = [1])
df2
# Out:
#    Total cases  Death Toll  Total Recovered
# 1   3200316391   110588070       1983135564

# %%
# bar graph for tatal cases, Death Toll and Recovered cases
plt.bar( d1.keys(), d1.values())
# Out:
# <BarContainer object of 3 artists>

# %%
confirmed_by_country = df.groupby('Country/Region')['Confirmed'].sum()
confirmed_by_country
# Out:
# Country/Region
# Australia            3801209
# Austria                    2
# Belgium              2112624
# Brazil             576684164
# Canada              28121337
# Chile               64740025
# Colombia            90213835
# Denmark                84215
# France               3455512
# Germany             52125814
# Hong Kong             688947
# India              632760702
# Iraq                       0
# Israel                     5
# Italy               62737971
# Japan                9854233
# Lebanon                    1
# Macau                  11319
# Mainland China      23444005
# Mexico              92691348
# Netherlands         18849561
# Others                 26228
# Pakistan            44749945
# Peru                97097878
# Russia             169120859
# Spain               98910912
# Sweden              14546863
# Taiwan                  1104
# UK                  76813234
# US                1009466764
# Ukraine             27205775
# ...

# %%
# pie chart for total comfirmed cases
explode = np.zeros(31)
explode[29]=0.1  # US
explode[11]=0.08  # India
explode[3]=0.06   #Brazil

axes = plt.subplots(figsize=(13,13))[1] 

temp=plt.pie(confirmed_by_country, labels = confirmed_by_country.index, explode = explode)[0]
axes.set_title('Tottal Confirmed Cases of Country')
# Out:
# Text(0.5, 1.0, 'Tottal Confirmed Cases of Country')

# %%
# pie chart for Death Toll
deaths_by_country = df.groupby('Country/Region')['Deaths'].sum()

explode = np.zeros(31)
explode[29]=0.1  # US
explode[3]=0.08  #Brazil
explode[11]=0.06   # India


axes = plt.subplots(figsize=(13,13))[1] 

temp=plt.pie(deaths_by_country, labels = deaths_by_country.index, explode = explode)[0]
axes.set_title('Death Toll Cases of Country')
# Out:
# Text(0.5, 1.0, 'Death Toll Cases of Country')

# %%
# pie chart for total Recovered cases
recovered_by_country = df.groupby('Country/Region')['Recovered'].sum()

explode = np.zeros(31)
explode[29]=0.1  # US
explode[3]=0.08  #Brazil
explode[11]=0.06   # India


axes = plt.subplots(figsize=(13,13))[1] 

temp=plt.pie(recovered_by_country, labels = recovered_by_country.index, explode = explode)[0]
axes.set_title('Recovered Cases of Country')
# Out:
# Text(0.5, 1.0, 'Recovered Cases of Country')

# %%
# Storing values of total deaths/confirmed/recovered for every provience of top 3 countries
index = df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending = False).head(3).index
 
filter_US = df['Country/Region'] == index[0]
filter_India = df['Country/Region'] == index[1]
filter_Brazil = df['Country/Region'] == index[2]
 
total_cases_state_US = df[filter_US].groupby('Province/State')['Confirmed'].sum()
total_cases_state_India = df[filter_India].groupby('Province/State')['Confirmed'].sum()
total_cases_state_Brazil = df[filter_Brazil].groupby('Province/State')['Confirmed'].sum()
 
death_toll_state_US = df[filter_US].groupby('Province/State')['Deaths'].sum()
death_toll_state_India = df[filter_India].groupby('Province/State')['Deaths'].sum()
death_toll_state_Brazil = df[filter_Brazil].groupby('Province/State')['Deaths'].sum()
 
recovered_by_state_US = df[filter_US].groupby('Province/State')['Recovered'].sum()
recovered_by_state_India = df[filter_India].groupby('Province/State')['Recovered'].sum()
recovered_by_state_Brazil = df[filter_Brazil].groupby('Province/State')['Recovered'].sum()

# %%
#For US
d_us={'Total Cases':total_cases_state_US,'Death Toll':death_toll_state_US, 'Recovered':recovered_by_state_US }
df_us= pd.DataFrame(d_us)
df_us
# Out:
#                        Total Cases  Death Toll  Recovered
# Province/State
#  Norfolk County, MA              7           0          0
# Alabama                   19202840      342513          0
# Alameda County, CA               6           0          0
# Alaska                     1064539        7079          0
# American Samoa                   0           0          0
# ...                            ...         ...        ...
# Williamson County, TN            5           0          0
# Wisconsin                 16944252      220390          8
# Wuhan Evacuee                    4           0          0
# Wyoming                     918842        7651          0
# Yolo County, CA                  4           0          0
#
# [199 rows x 3 columns]

# %%
plt.figure(figsize=(50,200))
plt.barh(df_us.index,df_us['Death Toll'])
# Out:
# <BarContainer object of 199 artists>

# %%
# For India
d_india={'Total Cases':total_cases_state_India,'Death Toll':death_toll_state_India, 'Recovered':recovered_by_state_India }
df_india= pd.DataFrame(d_india)
df_india
# Out:
#                                           Total Cases  Death Toll  Recovered
# Province/State
# Andaman and Nicobar Islands                    374074        5013     325481
# Andhra Pradesh                               64750563      552415   56445495
# Arunachal Pradesh                              940928        2084     733840
# Assam                                        16786178       62976   14126667
# Bihar                                        18435315       92677   16443660
# Chandigarh                                     999689       14333     827611
# Chhattisgarh                                 10700748      105203    8301747
# Dadar Nagar Haveli                                 22           0          2
# Dadra and Nagar Haveli and Daman and Diu       308019         249     276506
# Delhi                                        33147471      715018   28824818
# Goa                                           3152152       39456    2666762
# ...

# %%
plt.figure(figsize=(50,100))
plt.barh(df_india.index,df_india['Death Toll'])
# Out:
# <BarContainer object of 38 artists>

# %%
# For Braizl
d_Brazil={'Total Cases':total_cases_state_Brazil,'Death Toll':death_toll_state_Brazil, 'Recovered':recovered_by_state_Brazil}
df_Brazil= pd.DataFrame(d_Brazil)
df_Brazil
# Out:
#                      Total Cases  Death Toll  Recovered
# Province/State
# Acre                     3763609       91783    2909621
# Alagoas                 11125428      283559   10046057
# Amapa                    6635914      101204    4599035
# Amazonas                19306842      620917   15470917
# Bahia                   36054558      786548   32640649
# Ceara                   32615600     1335626   26955002
# Distrito Federal        22448833      359230   19991935
# Espirito Santo          16674966      469834   14104435
# Goias                   21216561      484222   18953422
# Maranhao                22885533      527468   20049176
# Mato Grosso             13133554      382509   10459395
# Mato Grosso do Sul       7227518      130320    6206117
# Minas Gerais            32362010      791302   27244495
# Para                    29941380     1005520   26848115
# Paraiba                 15409191      352756   10034357
# ...

# %%
plt.figure(figsize=(50,50))
plt.barh(df_Brazil.index,df_Brazil['Death Toll'])
# Out:
# <BarContainer object of 28 artists>

# %% [markdown]
# # Death and Recovery Percentage

# %%
death_sum = df.groupby('Country/Region')['Deaths'].sum()
confirmed_sum = df.groupby('Country/Region')['Confirmed'].sum()
recovered_sum = df.groupby('Country/Region')['Recovered'].sum()
 
d_percentages = {'Confirmed Sum' : confirmed_sum, 
                'Death Sum' : death_sum, 
                'Recovered Sum' : recovered_sum}
 
df_percentages = pd.DataFrame(d_percentages)
df_percentages['Death %'] = (df_percentages['Death Sum'] / df_percentages['Confirmed Sum']) * 100
df_percentages['Recover %'] = (df_percentages['Recovered Sum'] / df_percentages['Confirmed Sum']) * 100
df_percentages.sort_values('Recover %', ascending = False)
# Out:
#                 Confirmed Sum  Death Sum  Recovered Sum    Death %  Recover %
# Country/Region
# Chile                64740025    1672531       59225883   2.583457  91.482638
# Macau                   11319          0           9955   0.000000  87.949466
# Mainland China       23444005    1185964       20516894   5.058709  87.514458
# Hong Kong              688947      10786         594532   1.565578  86.295753
# Pakistan             44749945     931241       38446569   2.080988  85.914226
# Japan                 9854233     219957        8425747   2.232107  85.503834
# India               632760702   10518329      526512500   1.662292  83.208786
# Brazil              576684164   18536424      476384935   3.214311  82.607598
# Germany              52125814    1738940       42784328   3.336044  82.078964
# Mexico               92691348    9799175       75924462  10.571834  81.911056
# Australia             3801209      91186        3085335   2.398868  81.167202
# ...

# %% [markdown]
# # Check your chances of dying if you are tested Positive

# %%
df_temp = df.copy()
df_temp.set_index([ 'ObservationDate', 'Province/State'], inplace = True)

# %%
df_temp['Death Rate'] = df_temp['Deaths'] / df_temp['Confirmed'] *100
df_temp['Death Rate'].fillna(0, inplace = True)

# %%
print(df['Province/State'].unique())
state = input("Enter The State/Privince You Visited")
filter_state = df['Province/State'] == state
while(True):
    date = input("Enter Your Date in the format : " + "Month/Date/Year")
    for_error = date.split('/')
    if int(for_error[0]) > 12 :
        print('Invalid Date, Format -> Month/Date/Year')
        continue
    if int(for_error[1]) > 31 :
        print('Invalid Date, Format -> Month/Date/Year')
        continue
    if int(for_error[2]) != 2020:
        print('Invalid Date, Format -> Month/Date/Year')
        continue
    break

df_temp.loc[date].loc[state]['Death Rate']
# Out:
# ['Beijing' 'Chongqing' 'Fujian' 'Gansu' 'Guangdong' 'Guangxi' 'Guizhou'
#  'Hainan' 'Hebei' 'Heilongjiang' 'Henan' 'Hong Kong' 'Hubei' 'Hunan'
#  'Inner Mongolia' 'Jiangsu' 'Jiangxi' 'Jilin' 'Liaoning' 'Macau' 'Ningxia'
#  'Qinghai' 'Shaanxi' 'Shandong' 'Shanghai' 'Shanxi' 'Sichuan' 'Taiwan'
#  'Tianjin' 'Tibet' 'Washington' 'Xinjiang' 'Yunnan' 'Zhejiang' 'Anhui'
#  'Chicago' 'Illinois' 'California' 'Arizona' 'Ontario' 'New South Wales'
#  'Victoria' 'British Columbia' 'Bavaria' 'Queensland' 'Chicago, IL'
#  'South Australia' 'Boston, MA' 'Los Angeles, CA' 'Orange, CA'
#  'Santa Clara, CA' 'Seattle, WA' 'Tempe, AZ' 'San Benito, CA'
#  'Toronto, ON' 'London, ON' 'Madison, WI' 'Cruise Ship'
#  'Diamond Princess cruise ship' 'San Diego County, CA' 'San Antonio, TX'
#  'Ashland, NE' 'Travis, CA' 'From Diamond Princess' 'Lackland, TX' 'None'
#  'Humboldt County, CA' 'Sacramento County, CA'
#  'Omaha, NE (From Diamond Princess)' 'Travis, CA (From Diamond Princess)'
# ...
